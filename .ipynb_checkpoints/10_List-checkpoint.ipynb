# %%
#list is muttable
l=[3,4,5,6]
l[0]
# Out:
# 3

# %%
l[0]=999
l[0]
# Out:
# 999

# %%
l.append(420)
l
# Out:
# [999, 4, 5, 6, 420]

# %%
l2=[20,444,87]
l.extend(l2)
print(l)
# Out:
# [999, 4, 5, 6, 420, 20, 444, 87]

# %%
l.insert(1,100) #insert 100 at index 1 
print(l)
# Out:
# [999, 100, 4, 5, 6, 420, 20, 444, 87, 1]

# %%
l.pop(1) #pop index 1
l
# Out:
# [999, 4, 5, 6, 420, 20, 444, 87, 1]

# %%
l.index(1)
# Out:
# 8

# %%
l.count(4)
# Out:
# 1

# %%
l.sort(reverse="True")
l
# Out:
# [999, 444, 420, 87, 20, 6, 5, 4, 1]

# %%
list=[90,76,12,89]
sorted(list)    #gives new loist
# Out:
# [12, 76, 89, 90]

# %%
list
# Out:
# [90, 76, 12, 89]

# %%
newlist=list.copy()
newlist
# Out:
# [90, 76, 12, 89]

# %%
x=[45,True,"hii",[6,89]]
x
# Out:
# [45, True, 'hii', [6, 89]]

# %%
x[1]
# Out:
# True

# %%
x[3]
# Out:
# [6, 89]

# %%
x[3][1]
# Out:
# 89

# %%
x[3][0]
# Out:
# 6

# %%
x1=[6,6,8]
x2=[1,4]
print(x1+x2)
print(x1)
print(x2)
# Out:
# [6, 6, 8, 1, 4]
# [6, 6, 8]
# [1, 4]

# %%
6 in x1
# Out:
# True

# %%
string=("sairaj-prithesh-prajwal-pavan")
list=string.split("-")
print(type(list))
# Out:
# <class 'list'>
