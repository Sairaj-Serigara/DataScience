# %%
#string is immutable
name="alice"
age=10
print("name is {} and age is {}".format(name,age))
# Out:
# name is alice and age is 10

# %%
print(f"my name is {name} and age is {age}")
# Out:
# my name is alice and age is 10

# %%
print(f"{'python':<10}") #left assignment in range of 10
print(f"{'python':>10}")
print(f"{'python':^10}")
# Out:
# python
#     python
#   python
