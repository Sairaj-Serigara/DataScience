# %%
a=11
b=2

# %%
a/b
# Out:
# 5.5

# %%
a//b
# Out:
# 5

# %%
b**2
# Out:
# 4

# %%
3**2
# Out:
# 9

# %%
a=5
b=5

# %%
a&b
# Out:
# 5

# %%
a|b
# Out:
# 5

# %%
c=5

# %%
c
# Out:
# 5

# %%
c+=5

# %%
c
# Out:
# 10
