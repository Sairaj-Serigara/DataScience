# %%
import numpy as np

# %%
arr=np.array([1,2,4,6,4,3,7,5,3,6,6,6,6,6])

# %%
np.mean(arr)
# Out:
# np.float64(4.642857142857143)

# %%
np.std(arr)
# Out:
# np.float64(1.756910553749835)

# %%
np.var(arr)
# Out:
# np.float64(3.0867346938775517)

# %%
np.min(arr)
# Out:
# np.int64(1)

# %%
np.max(arr)
# Out:
# np.int64(7)

# %%
np.argmin(arr)   mini index
# Out:
# np.int64(0)

# %%
np.argmax(arr)
# Out:
# np.int64(6)

# %%
np.sum(arr)
# Out:
# np.int64(65)

# %%
np.prod(arr)
# Out:
# np.int64(470292480)

# %%
np.diff(arr)   #finds the difference between consecutive elements.
# Out:
# array([ 1,  2,  2, -2, -1,  4, -2, -2,  3,  0,  0,  0,  0])

# %%
np.percentile(arr, 50)  # For the 50th percentile (median)
# Out:
# np.float64(5.5)

# %%
# np.corrcoef(arr1, arr2)

# %%
np.unique(arr)  #removes dupli
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
np.cumsum(arr)
# Out:
# array([ 1,  3,  7, 13, 17, 20, 27, 32, 35, 41, 47, 53, 59, 65])

# %%
np.linspace(0, 10, 5)  # 5 numbers from 0 to 10
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
np.log(arr)
# Out:
# array([0.        , 0.69314718, 1.38629436, 1.79175947, 1.38629436,
#        1.09861229, 1.94591015, 1.60943791, 1.09861229, 1.79175947,
#        1.79175947, 1.79175947, 1.79175947, 1.79175947])

# %%
np.exp(arr)
# Out:
# array([   2.71828183,    7.3890561 ,   54.59815003,  403.42879349,
#          54.59815003,   20.08553692, 1096.63315843,  148.4131591 ,
#          20.08553692,  403.42879349,  403.42879349,  403.42879349,
#         403.42879349,  403.42879349])
