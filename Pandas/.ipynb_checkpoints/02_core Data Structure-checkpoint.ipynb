# %%
import pandas as pd

# %%
s1=pd.Series([10,20,30,40,50])
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s2=pd.Series([10,20,30,40,50],index=["sai","saiii","idk","some","no"])
s2
# Out:
# sai      10
# saiii    20
# idk      30
# some     40
# no       50
# dtype: int64

# %%
s2["sai"]
# Out:
# np.int64(10)

# %%
#Dataframe:2D array with rows and columns

# %%
data={
    "name":["sai","prithesh","sacchu"],
    "age":[20,20,20],
    "city":["hebri","shirva","bantakal"]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#        name  age      city
# 0       sai   20     hebri
# 1  prithesh   20    shirva
# 2    sacchu   20  bantakal

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
