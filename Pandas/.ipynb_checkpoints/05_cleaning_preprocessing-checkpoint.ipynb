# %%
import pandas as pd

# %%
df=pd.read_csv("data_cleaning_sample.csv")
df
# Out:
#       name   age          city gender              email   join date
# 0    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 1      Bob  30.0  loss angeles      M      bob@gmail.com  04-06-2020
# 2  Charlie   NaN         delhi      F  charlie@gmail.com  05-06-2027
# 3    David  22.0  Mumbai delhi      M    david@gmail.com  05-03-2022
# 4      NaN  29.0         delhi      F      eve@gmail.com         NaN
# 5    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 6  Charlie   NaN         delhi      F  charlie@gmail.com  05-06-2027

# %%
df.isnull()    #where the entry is null
# Out:
#     name    age   city  gender  email  join date
# 0  False  False  False   False  False      False
# 1  False  False  False   False  False      False
# 2  False   True  False   False  False      False
# 3  False  False  False   False  False      False
# 4   True  False  False   False  False       True
# 5  False  False  False   False  False      False
# 6  False   True  False   False  False      False

# %%
df.isnull().sum()      #writtens number of entrien null in the columns
# Out:
# name         1
# age          2
# city         0
# gender       0
# email        0
# join date    1
# dtype: int64

# %%
df.dropna()   #returns the rows where there is no null entry
# Out:
#     name   age          city gender            email   join date
# 0  Alice  25.0      banglore      M  alice@gmail.com  05-12-2023
# 1    Bob  30.0  loss angeles      M    bob@gmail.com  04-06-2020
# 3  David  22.0  Mumbai delhi      M  david@gmail.com  05-03-2022
# 5  Alice  25.0      banglore      M  alice@gmail.com  05-12-2023

# %%
df.dropna(axis=1) #returns the column where there is no null entries
# Out:
#            city gender              email
# 0      banglore      M    alice@gmail.com
# 1  loss angeles      M      bob@gmail.com
# 2         delhi      F  charlie@gmail.com
# 3  Mumbai delhi      M    david@gmail.com
# 4         delhi      F      eve@gmail.com
# 5      banglore      M    alice@gmail.com
# 6         delhi      F  charlie@gmail.com

# %%
df.fillna(0)
# Out:
#       name   age          city gender              email   join date
# 0    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 1      Bob  30.0  loss angeles      M      bob@gmail.com  04-06-2020
# 2  Charlie   0.0         delhi      F  charlie@gmail.com  05-06-2027
# 3    David  22.0  Mumbai delhi      M    david@gmail.com  05-03-2022
# 4        0  29.0         delhi      F      eve@gmail.com           0
# 5    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 6  Charlie   0.0         delhi      F  charlie@gmail.com  05-06-2027

# %%
df["age"].fillna(df["age"].mean())   #for the age column fill null value with mean of age
# Out:
# 0    25.0
# 1    30.0
# 2    26.2
# 3    22.0
# 4    29.0
# 5    25.0
# 6    26.2
# Name: age, dtype: float64

# %%
df.fillna(method="ffill")  #replace null value with last know value
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19608\3297729046.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")  #replace null value with last know value
#       name   age          city gender              email   join date
# 0    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 1      Bob  30.0  loss angeles      M      bob@gmail.com  04-06-2020
# 2  Charlie  30.0         delhi      F  charlie@gmail.com  05-06-2027
# 3    David  22.0  Mumbai delhi      M    david@gmail.com  05-03-2022
# 4    David  29.0         delhi      F      eve@gmail.com  05-03-2022
# 5    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 6  Charlie  25.0         delhi      F  charlie@gmail.com  05-06-2027

# %%
df.fillna(method="bfill")   #replace null value with last know value from  backward
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19608\2132280068.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")   #replace null value with last know value from  backward
#       name   age          city gender              email   join date
# 0    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 1      Bob  30.0  loss angeles      M      bob@gmail.com  04-06-2020
# 2  Charlie  22.0         delhi      F  charlie@gmail.com  05-06-2027
# 3    David  22.0  Mumbai delhi      M    david@gmail.com  05-03-2022
# 4    Alice  29.0         delhi      F      eve@gmail.com  05-12-2023
# 5    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 6  Charlie   NaN         delhi      F  charlie@gmail.com  05-06-2027

# %%
#solution of the above warning
df.ffill()
# Out:
#       name   age          city gender              email   join date
# 0    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 1      Bob  30.0  loss angeles      M      bob@gmail.com  04-06-2020
# 2  Charlie  30.0         delhi      F  charlie@gmail.com  05-06-2027
# 3    David  22.0  Mumbai delhi      M    david@gmail.com  05-03-2022
# 4    David  29.0         delhi      F      eve@gmail.com  05-03-2022
# 5    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 6  Charlie  25.0         delhi      F  charlie@gmail.com  05-06-2027

# %%
df
# Out:
#       name   age          city gender              email   join date
# 0    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 1      Bob  30.0  loss angeles      M      bob@gmail.com  04-06-2020
# 2  Charlie   NaN         delhi      F  charlie@gmail.com  05-06-2027
# 3    David  22.0  Mumbai delhi      M    david@gmail.com  05-03-2022
# 4      NaN  29.0         delhi      F      eve@gmail.com         NaN
# 5    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 6  Charlie   NaN         delhi      F  charlie@gmail.com  05-06-2027

# %%
df.duplicated()    #returns in which rows there are duplicate entries
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
df.drop_duplicates()   #removes duplicte rows
# Out:
#       name   age          city gender              email   join date
# 0    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 1      Bob  30.0  loss angeles      M      bob@gmail.com  04-06-2020
# 2  Charlie   NaN         delhi      F  charlie@gmail.com  05-06-2027
# 3    David  22.0  Mumbai delhi      M    david@gmail.com  05-03-2022
# 4      NaN  29.0         delhi      F      eve@gmail.com         NaN

# %%
df.duplicated(subset=["name","age"])   #checks where name and age are pair are similar
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
df["name"].str.lower()
# Out:
# 0      alice
# 1        bob
# 2    charlie
# 3      david
# 4        NaN
# 5      alice
# 6    charlie
# Name: name, dtype: object

# %%
df["city"].str.contains("Delhi",case=False)  #city contains delhi and casesensitive false
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# Name: city, dtype: bool

# %%
df["email"].str.split("@")   # splits to list
# Out:
# 0      [alice, gmail.com]
# 1        [bob, gmail.com]
# 2    [charlie, gmail.com]
# 3      [david, gmail.com]
# 4        [eve, gmail.com]
# 5      [alice, gmail.com]
# 6    [charlie, gmail.com]
# Name: email, dtype: object

# %%
df1=df.dropna().copy()
df1
# Out:
#     name   age          city gender            email   join date
# 0  Alice  25.0      banglore      M  alice@gmail.com  05-12-2023
# 1    Bob  30.0  loss angeles      M    bob@gmail.com  04-06-2020
# 3  David  22.0  Mumbai delhi      M  david@gmail.com  05-03-2022
# 5  Alice  25.0      banglore      M  alice@gmail.com  05-12-2023

# %%
df1["age"]=df1["age"].astype(int)
df1
# Out:
#     name  age          city gender            email   join date
# 0  Alice   25      banglore      M  alice@gmail.com  05-12-2023
# 1    Bob   30  loss angeles      M    bob@gmail.com  04-06-2020
# 3  David   22  Mumbai delhi      M  david@gmail.com  05-03-2022
# 5  Alice   25      banglore      M  alice@gmail.com  05-12-2023

# %%
df1.info()   #age is int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       4 non-null      object
#  1   age        4 non-null      int64
#  2   city       4 non-null      object
#  3   gender     4 non-null      object
#  4   email      4 non-null      object
#  5   join date  4 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 224.0+ bytes

# %%
df1["age group"]=df1["age"].apply(lambda x:"adult" if x>25 else "minor")   #creates a age group 
df1
# Out:
#     name  age          city gender            email   join date age group
# 0  Alice   25      banglore      M  alice@gmail.com  05-12-2023     minor
# 1    Bob   30  loss angeles      M    bob@gmail.com  04-06-2020     adult
# 3  David   22  Mumbai delhi      M  david@gmail.com  05-03-2022     minor
# 5  Alice   25      banglore      M  alice@gmail.com  05-12-2023     minor

# %%
#step 2pf above

def isminor(x):
    return "adult" if x>25 else "minor"
df1["age group"]=df1["age"].apply(isminor)
df1
# Out:
#     name  age          city gender            email   join date age group
# 0  Alice   25      banglore      M  alice@gmail.com  05-12-2023     minor
# 1    Bob   30  loss angeles      M    bob@gmail.com  04-06-2020     adult
# 3  David   22  Mumbai delhi      M  david@gmail.com  05-03-2022     minor
# 5  Alice   25      banglore      M  alice@gmail.com  05-12-2023     minor

# %%
df1
# Out:
#     name  age          city gender            email   join date age group
# 0  Alice   25      banglore      M  alice@gmail.com  05-12-2023     minor
# 1    Bob   30  loss angeles      M    bob@gmail.com  04-06-2020     adult
# 3  David   22  Mumbai delhi      M  david@gmail.com  05-03-2022     minor
# 5  Alice   25      banglore      M  alice@gmail.com  05-12-2023     minor

# %%
gender_map={"M":"Male","F":"Female"}   #replace m with male
df1["gender"]=df1["gender"].map(gender_map)
df1
# Out:
#     name  age          city gender            email   join date age group
# 0  Alice   25      banglore   Male  alice@gmail.com  05-12-2023     minor
# 1    Bob   30  loss angeles   Male    bob@gmail.com  04-06-2020     adult
# 3  David   22  Mumbai delhi   Male  david@gmail.com  05-03-2022     minor
# 5  Alice   25      banglore   Male  alice@gmail.com  05-12-2023     minor

# %%
df1=df1["city"].replace({"delhi":"newdelhi","banglore":"bangaloru"})

# %%
df1
# Out:
#     name  age          city gender            email   join date age group
# 0  Alice   25      banglore   Male  alice@gmail.com  05-12-2023     minor
# 1    Bob   30  loss angeles   Male    bob@gmail.com  04-06-2020     adult
# 3  David   22  Mumbai delhi   Male  david@gmail.com  05-03-2022     minor
# 5  Alice   25      banglore   Male  alice@gmail.com  05-12-2023     minor

# %%
df
# Out:
#       name   age          city gender              email   join date
# 0    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 1      Bob  30.0  loss angeles      M      bob@gmail.com  04-06-2020
# 2  Charlie   NaN         delhi      F  charlie@gmail.com  05-06-2027
# 3    David  22.0  Mumbai delhi      M    david@gmail.com  05-03-2022
# 4      NaN  29.0         delhi      F      eve@gmail.com         NaN
# 5    Alice  25.0      banglore      M    alice@gmail.com  05-12-2023
# 6  Charlie   NaN         delhi      F  charlie@gmail.com  05-06-2027
