# %%
import pandas as pd

# %%
df=pd.read_csv("movies.csv")
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df2=df.drop(df[df["year"]>1980].index)
df2
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# ..                                             ...    ...        ...   ...
# 87                             The Gong Show Movie      R     Comedy  1980
# 88                                      Gilda Live      R     Comedy  1980
# 89                                Why Would I Lie?     PG     Comedy  1980
# 90                                    First Family      R     Comedy  1980
# 91                             Mantis Fist Fighter    NaN     Action  1980
#
# ...

# %%
df3=df2.sort_values("score",ascending=False) #descending
df3
# Out:
#                                               name rating      genre  year  \
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 0                                      The Shining      R      Drama  1980
# 49                              Lion of the Desert     PG  Biography  1980
# 7                                      Raging Bull      R  Biography  1980
# 66                Moscow Does Not Believe in Tears     PG     Comedy  1980
# ..                                             ...    ...        ...   ...
# 47                                  The Boogey Man      R     Horror  1980
# 87                             The Gong Show Movie      R     Comedy  1980
# 90                                    First Family      R     Comedy  1980
# 52                            Can't Stop the Music     PG  Biography  1980
# 80                                          Phobia      R      Drama  1980
#
# ...

# %%
#df3.reset_index(drop="True")   #in the above cell index are mixed ,,it will resets the index form 0.... And it doesnot effect the df3
                    #cretes new col of index (to drop nwe index col drop=True )

# %%
df3
# Out:
#                                               name rating      genre  year  \
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 0                                      The Shining      R      Drama  1980
# 49                              Lion of the Desert     PG  Biography  1980
# 7                                      Raging Bull      R  Biography  1980
# 66                Moscow Does Not Believe in Tears     PG     Comedy  1980
# ..                                             ...    ...        ...   ...
# 47                                  The Boogey Man      R     Horror  1980
# 87                             The Gong Show Movie      R     Comedy  1980
# 90                                    First Family      R     Comedy  1980
# 52                            Can't Stop the Music     PG  Biography  1980
# 80                                          Phobia      R      Drama  1980
#
# ...

# %%
df3.sort_index()
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# ..                                             ...    ...        ...   ...
# 87                             The Gong Show Movie      R     Comedy  1980
# 88                                      Gilda Live      R     Comedy  1980
# 89                                Why Would I Lie?     PG     Comedy  1980
# 90                                    First Family      R     Comedy  1980
# 91                             Mantis Fist Fighter    NaN     Action  1980
#
# ...

# %%
df2.sort_values(["score","votes"])   #firstly it sort by score if columns of score are same then it sort by votes
df2
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# ..                                             ...    ...        ...   ...
# 87                             The Gong Show Movie      R     Comedy  1980
# 88                                      Gilda Live      R     Comedy  1980
# 89                                Why Would I Lie?     PG     Comedy  1980
# 90                                    First Family      R     Comedy  1980
# 91                             Mantis Fist Fighter    NaN     Action  1980
#
# ...

# %%
#df.reset_index(drop=True,inplace=True) do not create a copy ,,,in original df changes

# %%
df2["rank"]=df2["score"].rank()   #gives a rank based on score
df2
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# ..                                             ...    ...        ...   ...
# 87                             The Gong Show Movie      R     Comedy  1980
# 88                                      Gilda Live      R     Comedy  1980
# 89                                Why Would I Lie?     PG     Comedy  1980
# 90                                    First Family      R     Comedy  1980
# 91                             Mantis Fist Fighter    NaN     Action  1980
#
# ...

# %%
#if you want a rank according to whose score is greater then
df2["rank"]=df2["score"].rank(ascending=False,method="dense")
df2
#dense gives the integer rank
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# ..                                             ...    ...        ...   ...
# 87                             The Gong Show Movie      R     Comedy  1980
# 88                                      Gilda Live      R     Comedy  1980
# 89                                Why Would I Lie?     PG     Comedy  1980
# 90                                    First Family      R     Comedy  1980
# 91                             Mantis Fist Fighter    NaN     Action  1980
#
# ...

# %%
df2[["name","year","genre","rating","votes","writer","star","country","runtime","budget","gross","director"]]
#gives columns based based on names given first
# Out:
#                                               name  year      genre rating  \
# 0                                      The Shining  1980      Drama      R
# 1                                  The Blue Lagoon  1980  Adventure      R
# 2   Star Wars: Episode V - The Empire Strikes Back  1980     Action     PG
# 3                                        Airplane!  1980     Comedy     PG
# 4                                       Caddyshack  1980     Comedy      R
# ..                                             ...   ...        ...    ...
# 87                             The Gong Show Movie  1980     Comedy      R
# 88                                      Gilda Live  1980     Comedy      R
# 89                                Why Would I Lie?  1980     Comedy     PG
# 90                                    First Family  1980     Comedy      R
# 91                             Mantis Fist Fighter  1980     Action    NaN
#
# ...

# %%
col=["writer"]+[col for col in df2.columns if col!="writer"]
df2=df2[col]
df2
#This code moves the "writer" column to the first position while keeping the other columns in their original order.
# Out:
#                      writer                                            name  \
# 0              Stephen King                                     The Shining
# 1   Henry De Vere Stacpoole                                 The Blue Lagoon
# 2            Leigh Brackett  Star Wars: Episode V - The Empire Strikes Back
# 3              Jim Abrahams                                       Airplane!
# 4        Brian Doyle-Murray                                      Caddyshack
# ..                      ...                                             ...
# 87             Chuck Barris                             The Gong Show Movie
# 88              Anne Beatts                                      Gilda Live
# 89            Hollis Hodges                                Why Would I Lie?
# 90               Buck Henry                                    First Family
# 91            Hsin-Yi Chang                             Mantis Fist Fighter
#
# ...
