# %%
a=5

# %%
b=8

# %%
a+b
# Out:
# 13

# %%
name="sai"

# %%
print(name)
# Out:
# sai

# %%
print(a)
# Out:
# 5

# %%
a="224"

# %%
b="331"

# %%
a+b
# Out:
# '224331'

# %%
int(a)+int(b) #type casting ,,,,no need to weite print in jupyter
# Out:
# 555
