# %%
#set is unorder,mutable ,unique collection of elements ,no duplicate values

# %%
empty_set=()
print(empty_set)
# Out:
# ()

# %%
set1={1,2,3,4}

# %%
type(set1)
# Out:
# set

# %%
type(set1)
# Out:
# set

# %%
set11={}
type(set11)
# Out:
# dict

# %%
list1=[2,3,2,2,2,4,5,6]
unique_ele=set(list1)
unique_ele
# Out:
# {2, 3, 4, 5, 6}

# %%
set1.add(999)
set1
# Out:
# {1, 2, 3, 4, 999}

# %%
set1.update([88])
set1
# Out:
# {1, 2, 3, 4, 88, 999}

# %%
set1.remove(88) #raises error if not found

# %% [markdown]
# set1.discard(88)  #doesnot raises eror if not found

# %%
set1.discard(999)   #doesnot raises error if not found

# %%
set1
# Out:
# {1, 2, 3, 4}

# %%
set1.pop()     #random
set1
# Out:
# {3, 4}

# %%
set2=set1.copy()
set2
# Out:
# {3, 4}

# %%
set1.clear()
set1
# Out:
# set()

# %%
set111={1,2,3,4,5}
set222={4,5,6,8}

# %%
set111.union(set222)
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
set111.intersection(set222)
# Out:
# {4, 5}

# %%
set111.difference(set222)
# Out:
# {1, 2, 3}

# %%
set111.issubset(set222)
# Out:
# False

# %%
set111.issuperset(set222)  #If Set A has everything that Set B has, then A is a superset of B.
# Out:
# False
