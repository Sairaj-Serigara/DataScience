# %%
name="sairaj"

# %%
name
# Out:
# 'sairaj'

# %%
name.upper()
# Out:
# 'SAIRAJ'

# %%
name.endswith("j")
# Out:
# True

# %%
s="  hello "  
s1=s.strip()  #removes space

# %%
fruite="banana,apple"   #string 
f=fruite.split(",")     #list
f 
type(f)
# Out:
# list

# %%
s1[0:-1]
# Out:
# 'hell'

# %%
s1[-5:1]
# Out:
# 'h'

# %%
s1[:5]
# Out:
# 'hello'
