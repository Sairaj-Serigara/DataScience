# %%
#dictionary is mutable and key-value paired collection

# %%
dic={}
type(dic)
# Out:
# dict

# %%
#type1
student={
    "name":"sai",
    "age":25
}
type(student)
# Out:
# dict

# %%
#type2
student1=dict(name="sai",age=20)
student1
# Out:
# {'name': 'sai', 'age': 20}

# %%
student["name4"]  #throws key error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 student["name4"]
#
# KeyError: 'name4'

# %%
res=student.get("name4")   #doesnor throws error
print(res)
# Out:
# None

# %%
student={
    "name":"sai",
    "age":25
}
(student)
# Out:
# {'name': 'sai', 'age': 25}

# %%
student["age"]=100

# %%
(student)
# Out:
# {'name': 'sai', 'age': 100}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
student.values()
# Out:
# dict_values(['sai', 100])

# %%
student.items()
# Out:
# dict_items([('name', 'sai'), ('age', 100)])

# %%
student.update({"age":26, "city":"Udupi"})

# %%
student
# Out:
# {'name': 'sai', 'age': 26, 'city': 'Udupi'}

# %%
student.pop("age")
# Out:
# 26

# %%
student.popitem()   #Remove last item
# Out:
# ('city', 'Udupi')

# %%
student.setdefault("phone", "9999999999")
# Out:
# '9999999999'
