# %%
#tuple is an orderd immutable collection of element .elements os tuple cannot be modified

# %%
t=(2,5,6,8,4)
type(t)
# Out:
# tuple

# %%
t[1]
# Out:
# 5

# %%
len(t)
# Out:
# 5

# %%
t[1]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 t[1]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
#packing
person=("saira",20)

#unpacking
name,age=person

# %%
name,age
# Out:
# ('saira', 20)

# %%
t.count(5)
# Out:
# 1

# %%
t.index(5)
# Out:
# 1
