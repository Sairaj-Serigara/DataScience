# %%
import json

# %%
obj={"Name":"sai","Age":25,"job":"Datascientist"}
res1=json.dumps(obj)
print(res1)
# Out:
# {"Name": "sai", "Age": 25, "job": "Datascientist"}

# %%
type(obj)
# Out:
# dict

# %%
type(res1)   #dict--->String
# Out:
# str

# %%
obj1='{"Name":"sai","Age":25,"job":"Datascientist"}'  #with coats 
type(obj1)
# Out:
# str

# %%
obj1=json.loads('{"Name":"sai","Age":25,"job":"Datascientist"}')
print(type(obj1))
# Out:
# <class 'dict'>

# %%
file=open("example.json","w")
json.dump(obj1,file)

# %%
file.close()

# %%
file1=open("example.json","r")
json.load(file1)
# Out:
# '{"Name":"sai","Age":25,"job":"Datascientist"}'

# %%
file1.close()
