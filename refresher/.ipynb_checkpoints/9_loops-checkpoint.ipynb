# %%
l=[12,45,56]
for i in l:
    print(i)
# Out:
# 12
# 45
# 56

# %%
for i in range(5,11):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9
# 10

# %%
count=0
while(count<3):
    print("hi")
    count+=1
# Out:
# hi
# hi
# hi

# %%
list=["apple","banana","orange"]
for i in list:
    if(i== "banana"):
        break
    print(i)
# Out:
# apple

# %%
list=["apple","banana","orange"]
for i in list:
    if(i== "banana"):
        continue
    print(i)
# Out:
# apple
# orange
