# %%
f=open("text.txt")

# %%
f.read()
# Out:
# 'Hi my name is sairaj'

# %%
f.close()

# %%
s1="i love python"

# %%
f1=open("sai.txt","w")

# %%
f1.write(s1)
# Out:
# 13

# %%
f1.close()

# %%
import os
if os.path.exists("ex1.txt"):
    os.remove("ex1.txt")
    print("removed succesfully")
else:
    print("not exists")
# Out:
# removed succesfully

# %%
with open("ex.txt","r") as file:
    content=file.read()
    print(content)
# Out:
# hiiiiiiiiii

# %%
with open("ex.txt","r") as file:
    line = file.readline()
    print(line)
# Out:
# hiiiiiiiiii

# %%
with open("ex.txt","r") as file:   
    lines = file.readlines()
    print(lines)
