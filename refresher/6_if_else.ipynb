# %%
a=18
if(a>=18):
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
b=42
if(b>50):
    print("greater than 50")
elif(b>30):
    print("greater than 30")
elif(b>40):
    print("greater than 40")
else:
    print("invalid")
# Out:
# greater than 30

# %%
def add(a,b):
    return(a+b)

# %%
add(2,8)
# Out:
# 10

# %%
def greet():
    print('good night')

# %%
greet()
# Out:
# good night
